# %%
import time, pandas as pd
from colorama import init, Fore
from textblob import TextBlob

# %%
init(autoreset = True)

# %%
try: 
    df = pd.read_csv("imdb_top_1000.csv")

except FileNotFoundError:
    print(Fore.RED + "Error: The file was not found.")

# %%
genres = sorted({g.strip() for xs in df["Genre"].dropna().str.split(", ") for g in xs})

# %%
def dots():
    for _ in range(3):
        print(Fore.YELLOW + ".", end="", flush=True)
time.sleep(0.5)

# %%
def senti(p):
    return "Positive :)" if p > 0 else "Negative" if p < 0 else "Neutral "

# %%
def recommend(genre=None, mood=None, rating=None, n=5):
    d = df
    if genre:
        d = d[d["Genre"].str.contains(genre, case=False, na=False)]
        if rating is not None:
            d = d[d["Rating"] >= rating]
        if d.empty:
            return "No suitable movie recommendations found"
        d, need_nonneg, out = d.sample(frac=1).reset_index(drop=True), bool(mood,),[]
        for _, r in d.iterrows():
            ov = r.get("Overview")
            if pd.isna(ov):
                continue
            pol = TextBlob(ov).sentiment.polarity
            if(not need_nonneg) or pol >= 0:
                out.append((r["Series_Title"], pol))
                if len(out) == n:
                    break
        return out if out else "No suitable movie recommendations found."

# %%
def show(recs, name):
    print(Fore.YELLOW + f"\n AI-Analyzed Movie Recommendations for {name}:")
    for i, (t,p) in enumerate(recs, 1):
        print(f"{Fore.CYAN}{i}.{t}(Polarity: {p:.2f}, {senti(p)})")

# %%
def get_genre():
    print(Fore.GREEN + "Available Genres: ", end="")
    for i, g in enumerate(genres, 1): print(f"{Fore.CYAN}{i}. {g}")
    print()
    while True:
        x = input(Fore.YELLOW + "Enter genre number or name: ").strip()
        if x.isdigit() and 1 <= int(x) <= len(genres): return genres[int(x) - 1]
        x = x.title()
        if x in genres: return x
        print(Fore.RED + "Invalid input. Try again.\n")

# %%
def get_rating():
    while True:
        x = input(Fore.YELLOW + "Enter minimum IMDB rating (7.6-9.3) or 'skip': ").strip()
        if x.lower() == "skip":
            return None
        try:
            r = float(x)
            if 7.6 <= r <= 9.3:
                return r
            print(Fore.RED + "Rating out of range. Try again. \n")
        
        except ValueError:
            print(Fore.RED + "Invalid input. Try again. \n")

# %%
print(Fore.BLUE + "Welcome to your personal movie recommendation assistant! \n")
name = input(Fore.YELLOW + "What's your name?").strip()
print(f"\n {Fore.GREEN} Great to meet you, {name}! \n")
print(Fore.BLUE + "\n Let's find the perfect movie for you! \n")
genre = get_genre()

mood = input(Fore.YELLOW + "How do you feel today? (Describe your mood):").strip()
print(Fore.BLUE + "\n Analyzing mood", end="", flush=True)
dots()
mp = TextBlob(mood).sentiment.polarity
md = "positive" if mp > 0 else "negative" if mp < 0 else "neutral"
print(f"\n{Fore.GREEN} Your mood is {md} (Polarity: {mp:.2f}).\n")

rating = get_rating()

print(f"{Fore.BLUE}\n Finding movies for {name}", end="", flush=True)
dots()
recs = recommend(genre=genre, mood=mood, rating=rating, n=5)
print(Fore.RED + recs + "\n") if isinstance(recs, str) else show(recs, name)

while True:
    a = input(Fore.YELLOW + "\n Would you like more recommendations? (yes/no): ").strip().lower()
    if a == "no":
        print(Fore.GREEN + f"\n Enjoy your movie picks, {name}!\n")
    
    break 
    if a == "yes":
        recs = recommend(genre=genre, mood=mood, rating=rating, n=5)
        print(Fore.RED + recs + "\n") if isinstance(recs, str) else show(recs, name)
    else:
        print(Fore.RED + "Invalid choice. Try again. \n")
# Out:
# Welcome to your personal movie recommendation assistant!
#
#
#   Great to meet you, Diksh!
#
#
#  Let's find the perfect movie for you!
#
# Available Genres: 1. Action
# 2. Action,Adventure
# 3. Action,Adventure,Biography
# 4. Action,Adventure,Comedy
# 5. Action,Adventure,Crime
# 6. Action,Adventure,Drama
# 7. Action,Adventure,Family
# 8. Action,Adventure,Fantasy
# 9. Action,Adventure,Horror
# 10. Action,Adventure,Mystery
# 11. Action,Adventure,Romance
# 12. Action,Adventure,Sci-Fi
# 13. Action,Adventure,Thriller
# 14. Action,Adventure,Western
# 15. Action,Biography,Crime
# 16. Action,Biography,Drama
# 17. Action,Comedy
# 18. Action,Comedy,Crime
# 19. Action,Comedy,Drama
# 20. Action,Comedy,Family
# 21. Action,Comedy,Fantasy
# 22. Action,Comedy,Horror
# 23. Action,Comedy,Mystery
# 24. Action,Comedy,Romance
# 25. Action,Comedy,Sci-Fi
# 26. Action,Comedy,Sport
# 27. Action,Crime,Drama
# 28. Action,Crime,Fantasy
# 29. Action,Crime,Mystery
# 30. Action,Crime,Sci-Fi
# 31. Action,Crime,Sport
# 32. Action,Crime,Thriller
# 33. Action,Drama,Family
# 34. Action,Drama,Fantasy
# 35. Action,Drama,History
# 36. Action,Drama,Horror
# 37. Action,Drama,Mystery
# 38. Action,Drama,Romance
# 39. Action,Drama,Sci-Fi
# 40. Action,Drama,Sport
# 41. Action,Drama,Thriller
# 42. Action,Drama,War
# 43. Action,Fantasy
# 44. Action,Fantasy,Horror
# 45. Action,Fantasy,Thriller
# 46. Action,Fantasy,War
# 47. Action,Horror
# 48. Action,Horror,Mystery
# 49. Action,Horror,Romance
# 50. Action,Horror,Sci-Fi
# 51. Action,Horror,Thriller
# 52. Action,Mystery,Sci-Fi
# 53. Action,Mystery,Thriller
# 54. Action,Sci-Fi
# 55. Action,Sci-Fi,Thriller
# 56. Action,Thriller
# 57. Action,Thriller,War
# 58. Adventure
# 59. Adventure,Biography
# 60. Adventure,Biography,Crime
# 61. Adventure,Biography,Drama
# 62. Adventure,Comedy
# 63. Adventure,Comedy,Drama
# 64. Adventure,Comedy,Family
# 65. Adventure,Comedy,Fantasy
# 66. Adventure,Comedy,Horror
# 67. Adventure,Comedy,Romance
# 68. Adventure,Comedy,Sci-Fi
# 69. Adventure,Crime,Mystery
# 70. Adventure,Drama
# 71. Adventure,Drama,Family
# 72. Adventure,Drama,Fantasy
# 73. Adventure,Drama,History
# 74. Adventure,Drama,Horror
# 75. Adventure,Drama,Romance
# 76. Adventure,Drama,Sci-Fi
# 77. Adventure,Drama,Thriller
# 78. Adventure,Drama,War
# 79. Adventure,Drama,Western
# 80. Adventure,Family
# 81. Adventure,Family,Fantasy
# 82. Adventure,Fantasy
# 83. Adventure,Fantasy,Mystery
# 84. Adventure,Horror
# 85. Adventure,Horror,Mystery
# 86. Adventure,Mystery,Sci-Fi
# 87. Adventure,Sci-Fi,Thriller
# 88. Animation,Action,Adventure
# 89. Animation,Action,Comedy
# 90. Animation,Adventure,Comedy
# 91. Animation,Adventure,Family
# 92. Animation,Comedy,Drama
# 93. Animation,Comedy,Family
# 94. Animation,Drama,Fantasy
# 95. Animation,Drama,Romance
# 96. Animation,Family,Fantasy
# 97. Animation,Fantasy
# 98. Biography,Comedy,Crime
# 99. Biography,Comedy,Drama
# 100. Biography,Crime,Drama
# 101. Biography,Drama
# 102. Biography,Drama,Family
# 103. Biography,Drama,History
# 104. Biography,Drama,Mystery
# 105. Biography,Drama,Romance
# 106. Biography,Drama,Sport
# 107. Biography,Drama,Thriller
# 108. Biography,History,Thriller
# 109. Comedy
# 110. Comedy,Crime
# 111. Comedy,Crime,Drama
# 112. Comedy,Crime,Thriller
# 113. Comedy,Drama
# 114. Comedy,Drama,Family
# 115. Comedy,Drama,Fantasy
# 116. Comedy,Drama,Horror
# 117. Comedy,Drama,Music
# 118. Comedy,Drama,Musical
# 119. Comedy,Drama,Romance
# 120. Comedy,Drama,Thriller
# 121. Comedy,Family
# 122. Comedy,Family,Fantasy
# 123. Comedy,Family,Musical
# 124. Comedy,Family,Romance
# 125. Comedy,Fantasy
# 126. Comedy,Fantasy,Horror
# 127. Comedy,Fantasy,Romance
# 128. Comedy,Horror
# 129. Comedy,Horror,Romance
# 130. Comedy,Horror,Sci-Fi
# 131. Comedy,Horror,Thriller
# 132. Comedy,Music
# 133. Comedy,Music,Romance
# 134. Comedy,Mystery
# 135. Comedy,Romance
# 136. Comedy,Romance,Sport
# 137. Comedy,Romance,Western
# 138. Comedy,Sci-Fi
# 139. Comedy,Western
# 140. Crime,Drama
# 141. Crime,Drama,Fantasy
# 142. Crime,Drama,History
# 143. Crime,Drama,Horror
# 144. Crime,Drama,Music
# 145. Crime,Drama,Mystery
# 146. Crime,Drama,Thriller
# 147. Crime,Horror,Thriller
# 148. Crime,Mystery,Thriller
# 149. Crime,Thriller
# 150. Drama
# 151. Drama,Family
# 152. Drama,Family,Fantasy
# 153. Drama,Family,Music
# 154. Drama,Fantasy
# 155. Drama,Fantasy,Horror
# 156. Drama,Fantasy,Music
# 157. Drama,Fantasy,Musical
# 158. Drama,Fantasy,Mystery
# 159. Drama,Fantasy,Romance
# 160. Drama,Fantasy,Thriller
# 161. Drama,Fantasy,War
# 162. Drama,History
# 163. Drama,History,Thriller
# 164. Drama,History,War
# 165. Drama,Horror
# 166. Drama,Horror,Musical
# 167. Drama,Horror,Mystery
# 168. Drama,Horror,Sci-Fi
# 169. Drama,Horror,Thriller
# 170. Drama,Music
# 171. Drama,Music,Romance
# 172. Drama,Musical,Romance
# 173. Drama,Mystery,Romance
# 174. Drama,Mystery,Sci-Fi
# 175. Drama,Mystery,Thriller
# 176. Drama,Mystery,War
# 177. Drama,Romance
# 178. Drama,Romance,Sci-Fi
# 179. Drama,Romance,Thriller
# 180. Drama,Romance,War
# 181. Drama,Sci-Fi
# 182. Drama,Sci-Fi,Thriller
# 183. Drama,Sport
# 184. Drama,Thriller
# 185. Drama,Thriller,War
# 186. Drama,War
# 187. Drama,Western
# 188. Fantasy,Horror
# 189. Fantasy,Horror,Thriller
# 190. Fantasy,Mystery,Thriller
# 191. Horror
# 192. Horror,Mystery
# 193. Horror,Mystery,Sci-Fi
# 194. Horror,Mystery,Thriller
# 195. Horror,Sci-Fi,Thriller
# 196. Horror,Thriller
# 197. Mystery,Romance,Sci-Fi
# 198. Mystery,Romance,Thriller
# 199. Mystery,Sci-Fi,Thriller
# 200. Mystery,Thriller
# 201. Mystery,Thriller,Western
# 202. Romance,Sci-Fi
# 203. Romance,Sci-Fi,Thriller
# 204. Sci-Fi
# 205. Sci-Fi,Thriller
# 206. Thriller
# 207. Thriller,War
#
#
#  Analyzing mood...
#  Your mood is positive (Polarity: 0.70).
#
#
#  Finding movies for Diksh...No suitable movie recommendations found.
